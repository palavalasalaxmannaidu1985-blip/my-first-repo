# %% [markdown]
# Hardware refers to the physical components of a computer that you can touch, such as the CPU or keyboard. Software refers to the programs and instructions that run on the hardware, like Windows or a web browser. For example, a CPU is hardware, while the Windows operating system is software.
